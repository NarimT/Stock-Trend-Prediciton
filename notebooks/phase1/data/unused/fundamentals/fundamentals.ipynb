# %%
import yfinance as yf
import pandas as pd

# %%
nvda = yf.Ticker("NVDA")

# %%
nvda.quarterly_balance_sheet
# Out:
#                                                     2025-07-31    2025-04-30  \
# Ordinary Shares Number                            2.434700e+10  2.438756e+10
# Share Issued                                      2.434700e+10  2.438756e+10
# Net Debt                                                   NaN           NaN
# Total Debt                                        1.059800e+10  1.028500e+10
# Tangible Book Value                               9.362100e+10  7.757600e+10
# ...                                                        ...           ...
# Receivables                                       2.780800e+10  2.213200e+10
# Accounts Receivable                               2.780800e+10  2.213200e+10
# Cash Cash Equivalents And Short Term Investments  5.399100e+10  5.269100e+10
# Other Short Term Investments                      4.235200e+10  3.745700e+10
# Cash And Cash Equivalents                         1.163900e+10  1.523400e+10
#
# ...

# %%
nvda.quarterly_balance_sheet.T.to_csv("data/fundamentals/nvda_quarterly_balance_sheet.csv")

# %%
nvda.quarterly_income_stmt
# Out:
#                                                       2025-07-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.533040e-01
# Normalized EBITDA                                   3.193700e+10
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  2.642200e+10
# Reconciled Depreciation                             6.690000e+08
# Reconciled Cost Of Revenue                          1.289000e+10
# EBITDA                                              3.193700e+10
# EBIT                                                3.126800e+10
# Net Interest Income                                 5.300000e+08
# Interest Expense                                    6.200000e+07
# Interest Income                                     5.920000e+08
# ...

# %%
nvda.quarterly_income_stmt.T.to_csv("data/fundamentals/nvda_quarterly_income_stmt.csv")

# %%
nvda.quarterly_cash_flow
# Out:
#                                                   2025-07-31    2025-04-30  \
# Free Cash Flow                                  1.347000e+10  2.618700e+10
# Repurchase Of Capital Stock                    -9.720000e+09 -1.409500e+10
# Repayment Of Debt                                        NaN           NaN
# Capital Expenditure                            -1.895000e+09 -1.227000e+09
# Income Tax Paid Supplemental Data                        NaN           NaN
# End Cash Position                               1.163900e+10  1.523400e+10
# Beginning Cash Position                         1.523400e+10  8.589000e+09
# Changes In Cash                                -3.595000e+09  6.645000e+09
# Financing Cash Flow                            -1.183300e+10 -1.555300e+10
# Cash Flow From Continuing Financing Activities -1.183300e+10 -1.555300e+10
# Net Other Financing Charges                    -1.869000e+09 -1.584000e+09
# ...

# %%
nvda.quarterly_financials.T.to_csv("data/fundamentals/nvda_quarterly_financials.csv")

# %%
nvda.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2025-11-19 15:00:00-05:00          1.24           NaN          NaN
# 2025-08-27 16:00:00-04:00          1.01          1.05         4.05
# 2025-05-28 16:00:00-04:00          0.75          0.81         8.02
# 2025-02-26 16:00:00-05:00          0.85          0.89         5.25
# 2024-11-20 16:00:00-05:00          0.75          0.81         8.52
# 2024-08-28 16:00:00-04:00          0.64          0.68         5.66
# 2024-05-22 16:00:00-04:00          0.56          0.61         9.74
# 2024-02-21 16:00:00-05:00          0.46          0.52        11.40
# 2023-11-21 16:00:00-05:00          0.34          0.40        18.73
# 2023-08-23 16:00:00-04:00          0.21          0.27        29.35
# 2023-05-24 16:00:00-04:00          0.09          0.11        18.80
# 2023-02-22 16:00:00-05:00          0.08          0.09         9.45
# 2022-11-16 16:00:00-05:00          0.07          0.06       -17.32
# ...

# %%
nvda.earnings_dates.to_csv("data/fundamentals/nvda_earnings_dates.csv")
