# %%
import pandas as pd

df = pd.read_csv("GDELT Events from BigQuery with Sentiment Score and News URL 2020 - 2025.csv")

# %%
df_sorted = df.sort_values(by=["SQLDATE"])
df_sorted
# Out:
#        GlobalEventID   SQLDATE   Actor1Name   Actor2Name  NumMentions  \
# 6027       962334001  20200103       NVIDIA          NaN           10
# 20662      896873828  20200105          NaN       NVIDIA           10
# 22493      896874757  20200105       NVIDIA          NaN           10
# 26970      896919953  20200105          NaN       NVIDIA            5
# 16103      896913037  20200105       LENOVO       NVIDIA            5
# ...              ...       ...          ...          ...          ...
# 37862     1249678950  20250614       NVIDIA       FRANCE            4
# 22209     1249662053  20250614       EUROPE       NVIDIA            3
# 22208     1249640972  20250614       EUROPE       NVIDIA            3
# 18610     1250192208  20250627  SOUTH KOREA       NVIDIA            2
# 18611     1250192209  20250627       NVIDIA  SOUTH KOREA            2
#
#        NumSources  NumArticles  EventCode  EventBaseCode  EventRootCode  \
# ...
