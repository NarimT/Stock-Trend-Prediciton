# %%
import torch
import talib
import pandas as pd
import numpy as np

# %%
torch.cuda.is_available()
# Out:
# True

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns=["open", "high", "low", "close"])
talib.RSI(df["close"])[:20]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14    47.786770
# 15    53.081506
# 16    53.341820
# 17    49.424534
# 18    48.634547
# 19    54.942809
# dtype: float64
